# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **LOADING DATASET**

# %%
df= pd.read_excel('Windfarm.xlsx')
df.head()
# Out:
#   Time(year-month-day h:m:s)  Wind speed at height of 10 meters (m/s)  \
# 0        2019-01-01 00:00:00                                    2.209
# 1        2019-01-01 00:15:00                                    1.828
# 2        2019-01-01 00:30:00                                    2.193
# 3        2019-01-01 00:45:00                                    2.654
# 4        2019-01-01 01:00:00                                    2.249
#
#    Wind direction at height of 10 meters (˚)  \
# 0                                     81.317
# 1                                     77.460
# 2                                     86.700
# 3                                     78.160
# 4                                     94.297
#
#    Wind speed at height of 30 meters (m/s)  \
# 0                                    1.991
# 1                                    1.698
# 2                                    2.313
# 3                                    2.494
# 4                                    2.192
#
# ...

# %%
#Checking for null values
df.isnull().any()
# Out:
# Time(year-month-day h:m:s)                       False
# Wind speed at height of 10 meters (m/s)          False
# Wind direction at height of 10 meters (˚)        False
# Wind speed at height of 30 meters (m/s)          False
# Wind direction at height of 30 meters (˚)        False
# Wind speed at height of 50 meters (m/s)          False
# Wind direction at height of 50 meters (˚)        False
# Wind speed - at the height of wheel hub (m/s)    False
# Wind speed - at the height of wheel hub (˚)      False
# Air temperature (°C)                             False
# Atmosphere (hpa)                                 False
# Relative humidity (%)                            False
# Power (MW)                                       False
# dtype: bool

# %%
#Creating a copy of the dataframe
dfcpy=df.copy()
dfcpy
# Out:
#       Time(year-month-day h:m:s)  Wind speed at height of 10 meters (m/s)  \
# 0            2019-01-01 00:00:00                                    2.209
# 1            2019-01-01 00:15:00                                    1.828
# 2            2019-01-01 00:30:00                                    2.193
# 3            2019-01-01 00:45:00                                    2.654
# 4            2019-01-01 01:00:00                                    2.249
# ...                          ...                                      ...
# 70171        2020-12-31 22:45:00                                    5.738
# 70172        2020-12-31 23:00:00                                    5.748
# 70173        2020-12-31 23:15:00                                    4.468
# 70174        2020-12-31 23:30:00                                    3.730
# 70175        2020-12-31 23:45:00                                    3.291
#
#        Wind direction at height of 10 meters (˚)  \
# ...

# %%
#renaming a column name
dfcpy.rename(columns = {'Power (MW)':'Power'}, inplace = True)
dfcpy.rename(columns={'Time(year-month-day h:m:s)':'Time'},inplace = True)
dfcpy
# Out:
#                       Time  Wind speed at height of 10 meters (m/s)  \
# 0      2019-01-01 00:00:00                                    2.209
# 1      2019-01-01 00:15:00                                    1.828
# 2      2019-01-01 00:30:00                                    2.193
# 3      2019-01-01 00:45:00                                    2.654
# 4      2019-01-01 01:00:00                                    2.249
# ...                    ...                                      ...
# 70171  2020-12-31 22:45:00                                    5.738
# 70172  2020-12-31 23:00:00                                    5.748
# 70173  2020-12-31 23:15:00                                    4.468
# 70174  2020-12-31 23:30:00                                    3.730
# 70175  2020-12-31 23:45:00                                    3.291
#
#        Wind direction at height of 10 meters (˚)  \
# 0                                         81.317
# ...

# %% [markdown]
# # **SPLITTING INTO DEPENDENT AND INDEPENDENT VARIABLES**

# %%
#dependent variable
y=dfcpy['Power']
y
# Out:
# 0         0.254383
# 1         0.329703
# 2         0.296306
# 3         0.187590
# 4         0.081005
#            ...
# 70171    13.633642
# 70172     6.869759
# 70173     4.352931
# 70174     7.185250
# 70175    12.384466
# Name: Power, Length: 70176, dtype: float64

# %%
#independent variable
X=dfcpy.drop(columns=['Power','Time'],axis=1)
X.head()
# Out:
#    Wind speed at height of 10 meters (m/s)  \
# 0                                    2.209
# 1                                    1.828
# 2                                    2.193
# 3                                    2.654
# 4                                    2.249
#
#    Wind direction at height of 10 meters (˚)  \
# 0                                     81.317
# 1                                     77.460
# 2                                     86.700
# 3                                     78.160
# 4                                     94.297
#
#    Wind speed at height of 30 meters (m/s)  \
# 0                                    1.991
# 1                                    1.698
# 2                                    2.313
# 3                                    2.494
# 4                                    2.192
#
#    Wind direction at height of 30 meters (˚)  \
# 0                                     74.814
# 1                                     75.048
# ...

# %% [markdown]
# # **SPLITTING THE DATASET INTO TRAINING AND TESTING**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
#0.3 indicates 30% test dataset and remaining 70% training dataset which is ideal size of dataset for ml algorithms training and testing

# %%
X_train
# Out:
#        Wind speed at height of 10 meters (m/s)  \
# 63536                                    1.631
# 21654                                    4.767
# 2093                                     1.602
# 61223                                   13.250
# 31193                                   10.090
# ...                                        ...
# 21243                                    7.177
# 45891                                    1.383
# 42613                                    4.724
# 43567                                   12.263
# 68268                                    7.835
#
#        Wind direction at height of 10 meters (˚)  \
# 63536                                    169.873
# 21654                                    294.853
# 2093                                     259.433
# 61223                                    288.053
# 31193                                    235.367
# ...                                          ...
# ...

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # **USING SUPPORT VECTOR REGRESSOR MODEL**

# %%
from sklearn.svm import SVR

# Choose regression method and set hyperparameter
svr_rbf=SVR(C=1.0, epsilon=0.2, kernel='rbf')

# Training of the regression model
svr_rbf.fit(X_train, y_train)
y_pred = svr_rbf.predict(X_test)

# %%
Acc=pd.DataFrame({'Actual_y_value':y_test,'Predicted_y_value':y_pred})
Acc
# Out:
#        Actual_y_value  Predicted_y_value
# 50585       41.646313          32.415215
# 1610        26.752834          33.485542
# 68970        0.186879           0.299251
# 66444        1.792049           0.562896
# 38116        0.140692           0.574437
# ...               ...                ...
# 43785        7.865973           7.361747
# 34494       49.145634          44.578929
# 30848        1.079351           2.239956
# 33926        0.900288           0.358880
# 54458       84.859420          63.514877
#
# [21053 rows x 2 columns]

# %% [markdown]
# # **VISUALIZATION OF MODEL'S PREDICTION**

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %% [markdown]
# Can also be represented as

# %%
g=plt.scatter(y_test, y_pred)
g.axes.set_yscale('log')
g.axes.set_xscale('log')
g.axes.set_xlabel('True Values ')
g.axes.set_ylabel('Predictions ')
g.axes.axis('equal')
g.axes.axis('square')
# Out:
# (8.912509381337454, 112.2018454301963, 8.912509381337454, 112.2018454301963)

# %% [markdown]
# MADE BY S.R. VIDHYAMBIKA
